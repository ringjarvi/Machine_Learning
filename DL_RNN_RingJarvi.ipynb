# %% [markdown]
# # Deep Learning - Recurrent Neural Networks

# %%
! pip install --upgrade tensorflow==2.0
# Out:
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.VerifiedHTTPSConnection object at 0x10bdde240>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/tensorflow/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.VerifiedHTTPSConnection object at 0x10bddea20>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/tensorflow/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.VerifiedHTTPSConnection object at 0x10bdde0b8>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/tensorflow/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.VerifiedHTTPSConnection object at 0x10bdde278>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/tensorflow/
# WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.VerifiedHTTPSConnection object at 0x10bdde8d0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /simple/tensorflow/
# Requirement already up-to-date: tensorflow==2.0 in /Users/rrj/anaconda3/lib/python3.7/site-packages (2.0.0)
# Requirement already satisfied, skipping upgrade: absl-py>=0.7.0 in /Users/rrj/anaconda3/lib/python3.7/site-packages (from tensorflow==2.0) (0.8.1)
# Requirement already satisfied, skipping upgrade: wrapt>=1.11.1 in /Users/rrj/anaconda3/lib/python3.7/site-packages (from tensorflow==2.0) (1.11.2)
# Requirement already satisfied, skipping upgrade: tensorboard<2.1.0,>=2.0.0 in /Users/rrj/anaconda3/lib/python3.7/site-packages (from tensorflow==2.0) (2.0.1)
# Requirement already satisfied, skipping upgrade: protobuf>=3.6.1 in /Users/rrj/anaconda3/lib/python3.7/site-packages (from tensorflow==2.0) (3.10.0)
# Requirement already satisfied, skipping upgrade: termcolor>=1.1.0 in /Users/rrj/anaconda3/lib/python3.7/site-packages (from tensorflow==2.0) (1.1.0)
# Requirement already satisfied, skipping upgrade: numpy<2.0,>=1.16.0 in /Users/rrj/anaconda3/lib/python3.7/site-packages (from tensorflow==2.0) (1.16.4)
# Requirement already satisfied, skipping upgrade: six>=1.10.0 in /Users/rrj/anaconda3/lib/python3.7/site-packages (from tensorflow==2.0) (1.12.0)
# Requirement already satisfied, skipping upgrade: keras-applications>=1.0.8 in /Users/rrj/anaconda3/lib/python3.7/site-packages (from tensorflow==2.0) (1.0.8)
# Requirement already satisfied, skipping upgrade: wheel>=0.26 in /Users/rrj/anaconda3/lib/python3.7/site-packages (from tensorflow==2.0) (0.33.4)
# Requirement already satisfied, skipping upgrade: grpcio>=1.8.6 in /Users/rrj/anaconda3/lib/python3.7/site-packages (from tensorflow==2.0) (1.24.3)
# Requirement already satisfied, skipping upgrade: keras-preprocessing>=1.0.5 in /Users/rrj/anaconda3/lib/python3.7/site-packages (from tensorflow==2.0) (1.1.0)
# Requirement already satisfied, skipping upgrade: opt-einsum>=2.3.2 in /Users/rrj/anaconda3/lib/python3.7/site-packages (from tensorflow==2.0) (3.1.0)
# Requirement already satisfied, skipping upgrade: tensorflow-estimator<2.1.0,>=2.0.0 in /Users/rrj/anaconda3/lib/python3.7/site-packages (from tensorflow==2.0) (2.0.1)
# Requirement already satisfied, skipping upgrade: astor>=0.6.0 in /Users/rrj/anaconda3/lib/python3.7/site-packages (from tensorflow==2.0) (0.8.0)
# Requirement already satisfied, skipping upgrade: gast==0.2.2 in /Users/rrj/anaconda3/lib/python3.7/site-packages (from tensorflow==2.0) (0.2.2)
# Requirement already satisfied, skipping upgrade: google-pasta>=0.1.6 in /Users/rrj/anaconda3/lib/python3.7/site-packages (from tensorflow==2.0) (0.1.7)
# Requirement already satisfied, skipping upgrade: setuptools>=41.0.0 in /Users/rrj/anaconda3/lib/python3.7/site-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow==2.0) (41.0.1)
# Requirement already satisfied, skipping upgrade: google-auth-oauthlib<0.5,>=0.4.1 in /Users/rrj/anaconda3/lib/python3.7/site-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow==2.0) (0.4.1)
# Requirement already satisfied, skipping upgrade: werkzeug>=0.11.15 in /Users/rrj/anaconda3/lib/python3.7/site-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow==2.0) (0.15.4)
# Requirement already satisfied, skipping upgrade: google-auth<2,>=1.6.3 in /Users/rrj/anaconda3/lib/python3.7/site-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow==2.0) (1.6.3)
# Requirement already satisfied, skipping upgrade: markdown>=2.6.8 in /Users/rrj/anaconda3/lib/python3.7/site-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow==2.0) (3.1.1)
# Requirement already satisfied, skipping upgrade: h5py in /Users/rrj/anaconda3/lib/python3.7/site-packages (from keras-applications>=1.0.8->tensorflow==2.0) (2.9.0)
# Requirement already satisfied, skipping upgrade: requests-oauthlib>=0.7.0 in /Users/rrj/anaconda3/lib/python3.7/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.1.0,>=2.0.0->tensorflow==2.0) (1.2.0)
# Requirement already satisfied, skipping upgrade: pyasn1-modules>=0.2.1 in /Users/rrj/anaconda3/lib/python3.7/site-packages (from google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow==2.0) (0.2.7)
# Requirement already satisfied, skipping upgrade: cachetools>=2.0.0 in /Users/rrj/anaconda3/lib/python3.7/site-packages (from google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow==2.0) (3.1.1)
# Requirement already satisfied, skipping upgrade: rsa>=3.1.4 in /Users/rrj/anaconda3/lib/python3.7/site-packages (from google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow==2.0) (4.0)
# Requirement already satisfied, skipping upgrade: requests>=2.0.0 in /Users/rrj/anaconda3/lib/python3.7/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.1.0,>=2.0.0->tensorflow==2.0) (2.22.0)
# Requirement already satisfied, skipping upgrade: oauthlib>=3.0.0 in /Users/rrj/anaconda3/lib/python3.7/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.1.0,>=2.0.0->tensorflow==2.0) (3.1.0)
# Requirement already satisfied, skipping upgrade: pyasn1<0.5.0,>=0.4.6 in /Users/rrj/anaconda3/lib/python3.7/site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow==2.0) (0.4.7)
# Requirement already satisfied, skipping upgrade: idna<2.9,>=2.5 in /Users/rrj/anaconda3/lib/python3.7/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.1.0,>=2.0.0->tensorflow==2.0) (2.8)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/rrj/anaconda3/lib/python3.7/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.1.0,>=2.0.0->tensorflow==2.0) (1.24.2)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /Users/rrj/anaconda3/lib/python3.7/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.1.0,>=2.0.0->tensorflow==2.0) (2019.6.16)
# Requirement already satisfied, skipping upgrade: chardet<3.1.0,>=3.0.2 in /Users/rrj/anaconda3/lib/python3.7/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.1.0,>=2.0.0->tensorflow==2.0) (3.0.4)

# %%
import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras import Sequential
from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.layers import SimpleRNN, GRU, LSTM, Embedding, Dense
from tensorflow.keras.datasets import imdb

# %% [markdown]
# We will be using the IMDB dataset outlined in the keras documentation [here](https://www.tensorflow.org/api_docs/python/tf/keras/datasets/imdb/load_data). We will be applying a supervised learning application to text where we predict the sentiment of the IMDB reviews.
#
# Take a look at the imports above. For the RNN based imports see the [RNN guide](https://www.tensorflow.org/guide/keras/rnn). For preprocessing using `sequence` we'll use [pad_sequence](https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/sequence/pad_sequences). For Embedding, see the [Embedding documentation](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Embedding).

# %%
maxlen = 100 # Only use sentences up to this many words
n = 20000 # Only use the most frequent n words
(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=n)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17465344/17464789 [==============================] - 48s 3us/step

# %%
x_train.shape
# Out:
# (25000,)

# %%
x_test.shape
# Out:
# (25000,)

# %%
for i in range(10):
    print(f"Element {i} has a length of {len(x_train[i])}")
# Out:
# Element 0 has a length of 218
# Element 1 has a length of 189
# Element 2 has a length of 141
# Element 3 has a length of 550
# Element 4 has a length of 147
# Element 5 has a length of 43
# Element 6 has a length of 123
# Element 7 has a length of 562
# Element 8 has a length of 233
# Element 9 has a length of 130

# %%
x_train[0][:10]
# Out:
# [1, 14, 22, 16, 43, 530, 973, 1622, 1385, 65]

# %%
x_train = sequence.pad_sequences(x_train, maxlen=maxlen)
x_test = sequence.pad_sequences(x_test, maxlen=maxlen)

# %%
x_train.shape, x_test.shape
# Out:
# ((25000, 100), (25000, 100))

# %% [markdown]
# Instead of representing the data as $n$ 0's and 1 one at the $i$th index, the data is provided as the values of $i$ for each word. Each data sample is a sequence of integers that represent the index of the word in our vocabulary. This saves on storage when compared to a vector that's as long as our vocabulary with all 0's and just one 1 as discussed in the lecture. We will be using the [Embedding layer](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Embedding) to adapt this for our neural network.

# %%
print(f"All values of the targets are integers with the following max and min values")
print(f"{y_train.max()}, {y_train.min()}")
# Out:
# All values of the targets are integers with the following max and min values
# 1, 0

# %% [markdown]
# We will build three networks, using basic RNNs, GRUs and LSTMs. We will then compare their performance in predicting the classes of reviews appropriately.

# %%
# Define simple_layers which will go into a Sequential model saved as my_simple
# Here we are creating a simple RNN using one SimpleRNN layer with a dropout and recurrent_dropout
# You will need to use an Embedding layer before that to convert the data appropriately
# Determine an embedding size and use that for your SimpleRNN layer's output dimensions as well
# Finally, create an output layer that applies to our dataset task of binary classification

# YOUR CODE HERE
simple_layers = [Embedding(input_dim = n, output_dim=200), SimpleRNN(200, dropout=0.1, recurrent_dropout=0.1),
                 Dense(1, activation='sigmoid')]
my_simple = Sequential(layers = simple_layers)

# %%
assert len(simple_layers) == 3
assert isinstance(simple_layers[0], Embedding)
assert isinstance(simple_layers[1], SimpleRNN)
assert isinstance(simple_layers[2], Dense)
assert simple_layers[0].output_dim == simple_layers[1].units
assert simple_layers[1].dropout > 0
assert simple_layers[1].recurrent_dropout > 0
assert my_simple

# %%
# %%time
my_simple.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
my_simple.fit(x_train, y_train, batch_size=32, epochs=1)
# Out:
# Train on 25000 samples
# 25000/25000 [==============================] - 58s 2ms/sample - loss: 0.6237 - accuracy: 0.6337
# CPU times: user 3min 42s, sys: 1min 22s, total: 5min 5s
# Wall time: 58.4 s

# %%
# Define gru_layers which will go into a Sequential model saved as my_gru
# Here we are creating an RNN using GRUs, add 1 GRU layer with a dropout and recurrent_dropout
# You will need to use an Embedding layer before that to convert the data appropriately
# Determine an embedding size and use that for your GRU layer's output dimensions as well
# Finally, create an output layer that applies to our dataset task of binary classification

# YOUR CODE HERE
gru_layers = [Embedding(input_dim = n, output_dim=200), GRU(200, dropout=0.1, recurrent_dropout=0.1),
                 Dense(1, activation='sigmoid')]
my_gru= Sequential(gru_layers)

# %%
assert len(gru_layers) == 3
assert isinstance(gru_layers[0], Embedding)
assert isinstance(gru_layers[1], GRU)
assert isinstance(gru_layers[2], Dense)
assert gru_layers[0].output_dim == gru_layers[1].units
assert gru_layers[1].dropout > 0
assert gru_layers[1].recurrent_dropout > 0
assert my_gru

# %%
# %%time
my_gru.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
my_gru.fit(x_train, y_train, batch_size=32, epochs=1)
# Out:
# Train on 25000 samples
# 25000/25000 [==============================] - 114s 5ms/sample - loss: 0.5880 - accuracy: 0.7293
# CPU times: user 8min 23s, sys: 4min 6s, total: 12min 30s
# Wall time: 1min 54s

# %%
# Define lstm_layers which will go into a Sequential model saved as my_lstm
# Here we are creating an RNN using LSTMs, add 1 LSTM layer with a dropout and recurrent_dropout
# You will need to use an Embedding layer before that to convert the data appropriately
# Determine an embedding size and use that for your LSTM layer's output dimensions as well
# Finally, create an output layer that applies to our dataset task of binary classification

# YOUR CODE HERE
lstm_layers = [Embedding(input_dim = n, output_dim=200), LSTM(200, dropout=0.1, recurrent_dropout=0.1),
                 Dense(1, activation='sigmoid')]
my_lstm = Sequential(lstm_layers)

# %%
assert len(lstm_layers) == 3
assert isinstance(lstm_layers[0], Embedding)
assert isinstance(lstm_layers[1], LSTM)
assert isinstance(lstm_layers[2], Dense)
assert lstm_layers[0].output_dim == lstm_layers[1].units
assert lstm_layers[1].dropout > 0
assert lstm_layers[1].recurrent_dropout > 0
assert my_lstm

# %%
# %%time
my_lstm.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
my_lstm.fit(x_train, y_train, batch_size=32, epochs=1)
# Out:
# Train on 25000 samples
# 25000/25000 [==============================] - 122s 5ms/sample - loss: 0.4502 - accuracy: 0.7872
# CPU times: user 9min 35s, sys: 4min 40s, total: 14min 15s
# Wall time: 2min 2s

# %%
# Evaluate your models on the test set and save the loss and accuracies to the appropriate variables:
# model_name_loss, model_name_acc

# YOUR CODE HERE
[my_simple_loss, my_simple_acc] = my_simple.evaluate(x_test, y_test)
[my_gru_loss, my_gru_acc] = my_gru.evaluate(x_test, y_test)
[my_lstm_loss, my_lstm_acc] = my_lstm.evaluate(x_test, y_test)
# Out:
# 25000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# 25000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# 25000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...

# %%
print(f"Your simple model achieved an accuracy of {my_simple_acc:.2}.")
print(f"Your GRU model achieved an accuracy of {my_gru_acc:.2}.")
print(f"Your LSTM model achieved an accuracy of {my_lstm_acc:.2}.")
# Out:
# Your simple model achieved an accuracy of 0.64.
# Your GRU model achieved an accuracy of 0.7.
# Your LSTM model achieved an accuracy of 0.83.

# %% [markdown]
# Note that we are only running these models with 1 layer and training them for only 1 epoch. We can easily achieve better results by stacking multiple layers but the model would take a much longer time to train.

# %%
assert my_simple_acc > 0.4
assert my_gru_acc > 0.6
assert my_lstm_acc > 0.7

# %% [markdown]
# ## Feedback

# %%
def feedback():
    """Provide feedback on the contents of this exercise
    
    Returns:
        string
    """
    # YOUR CODE HERE
    return"This was informative."
